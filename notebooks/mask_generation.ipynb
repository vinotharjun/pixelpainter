# %%
import os
import itertools
import matplotlib
import matplotlib.pyplot as plt

# %%
from painter.data.genmask import MaskGenerator

# %%
from PIL import Image
import numpy as np
Image.fromarray(np.uint8(mask_generator.sample())*255)
# Out:
# <PIL.Image.Image image mode=RGB size=192x192 at 0x26E47D4FBB0>

# %%
# Instantiate mask generator
mask_generator = MaskGenerator(192, 192, 3, rand_seed=42)

# Plot the results
_, axes = plt.subplots(5, 5, figsize=(20, 20))
axes = list(itertools.chain.from_iterable(axes))

for i in range(len(axes)):
    # Generate image
    img = mask_generator.sample()
    # Plot image on axis
    axes[i].imshow(img*255)

# %%
# Instantiate mask generator
mask_generator = MaskGenerator(192, 192, 3, rand_seed=42, filepath='./painter/dataset/masks/')

# Plot the results
_, axes = plt.subplots(5, 5, figsize=(20, 20))
axes = list(itertools.chain.from_iterable(axes))

for i in range(len(axes)):
    
    # Generate image
    img = mask_generator.sample()
    # Plot image on axis
    axes[i].imshow(img*255)
# Out:
# >> Found 55116 masks in ./painter/dataset/masks/
