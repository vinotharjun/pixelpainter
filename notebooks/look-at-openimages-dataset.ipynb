# %%
import sys;sys.path.append("../")
from painter.data.openimages_dataset import OpenImages
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = OpenImages((192,192),datatype="validation")
# Out:
# >> Found 12000 masks in D:\myown\storage\inpainting-dataset\masks\validation

# %%
from painter.utils import *

# %%
import matplotlib.pyplot as plt
# Load image
i=11
dataset = data[i]

img = dataset["ground_truth"]
shape = img.shape
print(f"Shape of image is: {shape}")

# Image + mask
masked_img =  dataset["input"]
mask = dataset["mask"]
# Show side by side
_, axes = plt.subplots(1, 3, figsize=(20, 5))
axes[0].imshow(im_convert(img,denormalize=True))
axes[1].imshow(im_convert(mask,denormalize=False)*255)
axes[2].imshow(im_convert(masked_img,denormalize=True))
plt.show()
print(minmax(mask),minmax(masked_img),minmax(img))
# Out:
# Shape of image is: torch.Size([3, 192, 192])
# (tensor(0.0039), tensor(0.)) (tensor(2.2566), tensor(-2.1179)) (tensor(2.2566), tensor(-2.0357))
